# %% [markdown]
# <a href="https://colab.research.google.com/github/kundajelab/locusselect/blob/master/examples/regression%20on%20200%20bp%20genome%20bins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "7"

# %%
#load dragonn tutorial utilities 
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from numpy.random import seed
seed(1234)

# %%
#!pip install locusselect

# %% [markdown]
# ## Regression H1ESC DNAse model (trained genomewide), fully connected layer embeddings

# %%
## generate embeddings at the -2 layer 
import locusselect 
from locusselect.embeddings import * 
from locusselect.interpret import * 
from locusselect.utils import * 
from locusselect.gapped_kmers import * 
import numpy as np

# %%
splits=list(range(10))
coord_prefix="/mnt/lab_data2/annashch/locusselect_examples/embedding_collapse_to_pc_h1esc/all_peaks/"
model_prefix="/srv/scratch/annashch/bias_correction/gc_covariate/regression/H1ESC/"
embedding_layer_names=["dense_2",'dense_5','dense_8','dense_11','dense_14','dense_17', 'dense_20','dense_23','dense_26','dense_29']
embedding_input_names=["input_1",'input_3','input_5','input_7','input_9','input_11','input_13','input_15','input_17','input_19']
'''
for split in splits: 
    #first, we get embeddings from the model fully connected layer 
    fc_embedding_args={"input_bed_file":coord_prefix+str(split)+".optimal_peak.narrowPeak",
                "model_hdf5":model_prefix+"DNASE.H1ESC.regressionlabels.withgc."+str(split),
                "ref_fasta":"/users/annashch/male.hg19.fa",
                "center_on_summit":True,
                "center_on_bed_interval":False,
                "flank":500,
                "embedding_layer_name":embedding_layer_names[split],
                "embedding_input_name":embedding_input_names[split],
                "expand_dims":True,
                "threads":20,
                "output_npz_file":str(split)+".summits_FC_layer_NN_embeddings.regression.gc.npz"}
    fc_regions, fc_embeddings = compute_embeddings(fc_embedding_args)
'''
# Out:
# '\nfor split in splits: \n    #first, we get embeddings from the model fully connected layer \n    fc_embedding_args={"input_bed_file":coord_prefix+str(split)+".optimal_peak.narrowPeak",\n                "model_hdf5":model_prefix+"DNASE.H1ESC.regressionlabels.withgc."+str(split),\n                "ref_fasta":"/users/annashch/male.hg19.fa",\n                "center_on_summit":True,\n                "center_on_bed_interval":False,\n                "flank":500,\n                "embedding_layer_name":embedding_layer_names[split],\n                "embedding_input_name":embedding_input_names[split],\n                "expand_dims":True,\n                "threads":20,\n                "output_npz_file":str(split)+".summits_FC_layer_NN_embeddings.regression.gc.npz"}\n    fc_regions, fc_embeddings = compute_embeddings(fc_embedding_args)\n'

# %%
## get the loci embeddings 
coord_prefix="/mnt/lab_data2/annashch/locusselect_examples/coordinates/"
loci=["MYC","SOX2","POU5F1","NANOG"]
splits=[9,2,3,8]
for index in range(len(loci)):
    locus=loci[index]
    split=splits[index]
    coords=coord_prefix+locus+".geneLocus.250bp.windows.hg19.bed"
    model=model_prefix+"DNASE.H1ESC.regressionlabels.withgc."+str(split)
    #first, we get embeddings from the model fully connected layer 
    fc_embedding_args={"input_bed_file":coords,
                   "model_hdf5":model,
                   "ref_fasta":"/users/annashch/male.hg19.fa",
                   "center_on_summit":False,
                   "center_on_bed_interval":True,
                   "flank":500,
                   "embedding_layer_name":embedding_layer_names[split],
                   "embedding_input_name":embedding_input_names[split],
                   "expand_dims":True,
                   "threads":20,
                   "output_npz_file":locus+"_FC_layer_NN_embeddings.regression.gc.npz"}
    fc_regions, fc_embeddings = compute_embeddings(fc_embedding_args)
# Out:
# got model architecture
# loaded model weights
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           (None, 1, 1000, 4)   0
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 1, 1000, 300) 23100       input_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 1, 1000, 300) 1200        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 1, 1000, 300) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 1, 333, 300)  0           activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 1, 333, 200)  660200      max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 1, 333, 200)  800         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 1, 333, 200)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 1, 83, 200)   0           activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 1, 83, 200)   280200      max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 1, 83, 200)   800         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 1, 83, 200)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 1, 20, 200)   0           activation_48[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 4000)         0           max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 1000)         4001000     flatten_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 1000)         4000        dense_28[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 1000)         0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 1000)         0           activation_49[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 1000)         1001000     dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 1000)         4000        dense_29[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 1000)         0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 1000)         0           activation_50[0][0]
# __________________________________________________________________________________________________
# input_20 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 1000)         0           dropout_20[0][0]
#                                                                  input_20[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 1)            1001        add_10[0][0]
# ==================================================================================================
# Total params: 5,977,301
# Trainable params: 5,971,901
# Non-trainable params: 5,400
# __________________________________________________________________________________________________
# None
# loaded model
# obtained embedding layer model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        (None, 1, 1000, 4)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 1, 1000, 300)      23100
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 1, 1000, 300)      1200
# _________________________________________________________________
# activation_46 (Activation)   (None, 1, 1000, 300)      0
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 1, 333, 300)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 1, 333, 200)       660200
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 1, 333, 200)       800
# _________________________________________________________________
# activation_47 (Activation)   (None, 1, 333, 200)       0
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 1, 83, 200)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 1, 83, 200)        280200
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 1, 83, 200)        800
# _________________________________________________________________
# activation_48 (Activation)   (None, 1, 83, 200)        0
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 1, 20, 200)        0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 4000)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1000)              4001000
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 1000)              4000
# _________________________________________________________________
# activation_49 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 1000)              1001000
# =================================================================
# Total params: 5,972,300
# Trainable params: 5,968,900
# Non-trainable params: 3,400
# _________________________________________________________________
# None
# created data generator from 0
# 1/1 [==============================] - 6s 6s/step
# created data generator from 1000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 2000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 3000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 4000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 5000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 6000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 7000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 8000
# 1/1 [==============================] - 1s 681ms/step
# got embeddings
# got region labels
# writing output file
# got model architecture
# loaded model weights
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 1, 1000, 4)   0
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1000, 300) 23100       input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 1, 1000, 300) 1200        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1, 1000, 300) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 1, 333, 300)  0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1, 333, 200)  660200      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 1, 333, 200)  800         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1, 333, 200)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 1, 83, 200)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 83, 200)   280200      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 1, 83, 200)   800         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 1, 83, 200)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 1, 20, 200)   0           activation_13[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 4000)         0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1000)         4001000     flatten_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1000)         4000        dense_7[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1000)         0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1000)         0           activation_14[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1000)         1001000     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1000)         4000        dense_8[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1000)         0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1000)         0           activation_15[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1000)         0           dropout_6[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            1001        add_3[0][0]
# ==================================================================================================
# Total params: 5,977,301
# Trainable params: 5,971,901
# Non-trainable params: 5,400
# __________________________________________________________________________________________________
# None
# loaded model
# obtained embedding layer model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 1, 1000, 4)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1000, 300)      23100
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 1, 1000, 300)      1200
# _________________________________________________________________
# activation_11 (Activation)   (None, 1, 1000, 300)      0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 333, 300)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1, 333, 200)       660200
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 1, 333, 200)       800
# _________________________________________________________________
# activation_12 (Activation)   (None, 1, 333, 200)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 83, 200)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 83, 200)        280200
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 1, 83, 200)        800
# _________________________________________________________________
# activation_13 (Activation)   (None, 1, 83, 200)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 20, 200)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4000)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1000)              4001000
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 1000)              4000
# _________________________________________________________________
# activation_14 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1000)              1001000
# =================================================================
# Total params: 5,972,300
# Trainable params: 5,968,900
# Non-trainable params: 3,400
# _________________________________________________________________
# None
# created data generator from 0
# 1/1 [==============================] - 3s 3s/step
# created data generator from 1000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 2000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 3000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 4000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 5000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 6000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 7000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 8000
# 1/1 [==============================] - 1s 682ms/step
# got embeddings
# got region labels
# writing output file
# got model architecture
# loaded model weights
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 1, 1000, 4)   0
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 1, 1000, 300) 23100       input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 1, 1000, 300) 1200        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 1, 1000, 300) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 1, 333, 300)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 333, 200)  660200      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 1, 333, 200)  800         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 1, 333, 200)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 1, 83, 200)   0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 83, 200)   280200      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 1, 83, 200)   800         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 1, 83, 200)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 1, 20, 200)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 4000)         0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1000)         4001000     flatten_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 1000)         4000        dense_10[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 1000)         0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 1000)         0           activation_19[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1000)         1001000     dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 1000)         4000        dense_11[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 1000)         0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 1000)         0           activation_20[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 1000)         0           dropout_8[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            1001        add_4[0][0]
# ==================================================================================================
# Total params: 5,977,301
# Trainable params: 5,971,901
# Non-trainable params: 5,400
# __________________________________________________________________________________________________
# None
# loaded model
# obtained embedding layer model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 1, 1000, 4)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1000, 300)      23100
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 1, 1000, 300)      1200
# _________________________________________________________________
# activation_16 (Activation)   (None, 1, 1000, 300)      0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 1, 333, 300)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 333, 200)       660200
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 1, 333, 200)       800
# _________________________________________________________________
# activation_17 (Activation)   (None, 1, 333, 200)       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 1, 83, 200)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 83, 200)        280200
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 1, 83, 200)        800
# _________________________________________________________________
# activation_18 (Activation)   (None, 1, 83, 200)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 1, 20, 200)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 4000)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1000)              4001000
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 1000)              4000
# _________________________________________________________________
# activation_19 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1000)              1001000
# =================================================================
# Total params: 5,972,300
# Trainable params: 5,968,900
# Non-trainable params: 3,400
# _________________________________________________________________
# None
# created data generator from 0
# 1/1 [==============================] - 3s 3s/step
# created data generator from 1000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 2000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 3000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 4000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 5000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 6000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 7000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 8000
# 1/1 [==============================] - 1s 728ms/step
# got embeddings
# got region labels
# writing output file
# got model architecture
# loaded model weights
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_17 (InputLayer)           (None, 1, 1000, 4)   0
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 1, 1000, 300) 23100       input_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 1, 1000, 300) 1200        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 1, 1000, 300) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 1, 333, 300)  0           activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 1, 333, 200)  660200      max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 1, 333, 200)  800         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 1, 333, 200)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 1, 83, 200)   0           activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 1, 83, 200)   280200      max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 1, 83, 200)   800         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 1, 83, 200)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 1, 20, 200)   0           activation_43[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 4000)         0           max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 1000)         4001000     flatten_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 1000)         4000        dense_25[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 1000)         0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 1000)         0           activation_44[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 1000)         1001000     dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 1000)         4000        dense_26[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 1000)         0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 1000)         0           activation_45[0][0]
# __________________________________________________________________________________________________
# input_18 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 1000)         0           dropout_18[0][0]
#                                                                  input_18[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1)            1001        add_9[0][0]
# ==================================================================================================
# Total params: 5,977,301
# Trainable params: 5,971,901
# Non-trainable params: 5,400
# __________________________________________________________________________________________________
# None
# loaded model
# obtained embedding layer model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 1, 1000, 4)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 1, 1000, 300)      23100
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 1, 1000, 300)      1200
# _________________________________________________________________
# activation_41 (Activation)   (None, 1, 1000, 300)      0
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 1, 333, 300)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 1, 333, 200)       660200
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 1, 333, 200)       800
# _________________________________________________________________
# activation_42 (Activation)   (None, 1, 333, 200)       0
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 1, 83, 200)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 1, 83, 200)        280200
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 1, 83, 200)        800
# _________________________________________________________________
# activation_43 (Activation)   (None, 1, 83, 200)        0
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 1, 20, 200)        0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 4000)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 1000)              4001000
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 1000)              4000
# _________________________________________________________________
# activation_44 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 1000)              1001000
# =================================================================
# Total params: 5,972,300
# Trainable params: 5,968,900
# Non-trainable params: 3,400
# _________________________________________________________________
# None
# created data generator from 0
# 1/1 [==============================] - 4s 4s/step
# created data generator from 1000
# 1/1 [==============================] - 3s 3s/step
# created data generator from 2000
# 1/1 [==============================] - 3s 3s/step
# created data generator from 3000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 4000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 5000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 6000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 7000
# 1/1 [==============================] - 2s 2s/step
# created data generator from 8000
# 1/1 [==============================] - 1s 1s/step
# got embeddings
# got region labels
# writing output file

# %%
#combine the loci embeddings into a single data frame 
all_embeddings=None
all_bed_entries=None
locus_to_pos={}
locus_suffix="_FC_layer_NN_embeddings.regression.gc.npz"
loci=["MYC","SOX2","POU5F1","NANOG"]
last_index=0
for locus in loci: 
    cur_embedding_data=np.load(locus+locus_suffix,allow_pickle=True)
    cur_bed_entries=cur_embedding_data['bed_entries']
    cur_embeddings=cur_embedding_data['embeddings']
    if all_embeddings is None: 
        all_embeddings=cur_embeddings 
        all_bed_entries=cur_bed_entries
    else: 
        all_embeddings=np.concatenate((all_embeddings,cur_embeddings),axis=0)
        all_bed_entries=np.concatenate((all_bed_entries,cur_bed_entries),axis=0)
    start_pos=last_index 
    end_pos=last_index+cur_embeddings.shape[0]
    last_index=end_pos 
    locus_to_pos[locus]=[start_pos,end_pos]

# %%
all_embeddings.shape
# Out:
# (113917, 1000)

# %%
locus_to_pos
# Out:
# {'MYC': [0, 8001],
#  'SOX2': [8001, 16002],
#  'POU5F1': [16002, 24003],
#  'NANOG': [24003, 32177]}

# %%
#augment with all peak embeddings 
splits=list(range(10))

for split in splits: 
    cur_embeddings_data=np.load(str(split)+".summits_FC_layer_NN_embeddings.regression.gc.npz",allow_pickle=True)
    cur_bed_entries=cur_embedding_data['bed_entries']
    cur_embeddings=cur_embedding_data['embeddings']
    all_embeddings=np.concatenate((all_embeddings,cur_embeddings),axis=0)
    all_bed_entries=np.concatenate((all_bed_entries,cur_bed_entries),axis=0)

# %%
all_bed_entries.shape
# Out:
# (195657,)

# %%
all_embeddings.shape
# Out:
# (195657, 1000)

# %%
# run PCA on the embeddings 
# Dimension reduction and clustering libraries
import umap
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
# Out:
# /users/annashch/miniconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# /users/annashch/miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
from sklearn.decomposition import PCA 
  
pca = PCA(n_components = 1000) 
  
pca_res = pca.fit_transform(all_embeddings)   
explained_variance = pca.explained_variance_ratio_ # verify that the PCA embeddings have same UMAP projection as original embeddings.

# %%
explained_variance[0:10]
np.cumsum(explained_variance)
# Out:
# array([0.48222491, 0.70398207, 0.84895986, 0.8928117 , 0.92378091,
#        0.93971502, 0.95307742, 0.96002548, 0.96366368, 0.96702953,
#        0.96959531, 0.97179697, 0.97373173, 0.97541354, 0.97694977,
#        0.97831551, 0.97961682, 0.98080307, 0.98197984, 0.98295909,
#        0.98382903, 0.98466118, 0.9854125 , 0.98612633, 0.98674422,
#        0.98731313, 0.9878274 , 0.98833105, 0.98879631, 0.98924412,
#        0.98967481, 0.99007944, 0.99045447, 0.99079855, 0.99113235,
#        0.99144325, 0.99171181, 0.99196694, 0.99221221, 0.99244999,
#        0.99267385, 0.99288818, 0.99309511, 0.99329516, 0.99349058,
#        0.99368062, 0.9938579 , 0.99403155, 0.99419915, 0.99436124,
#        0.99450906, 0.99465095, 0.99478932, 0.99491923, 0.99504757,
#        0.99517134, 0.99528711, 0.99539794, 0.99550598, 0.99561136,
#        0.99571397, 0.99581058, 0.99590282, 0.99599131, 0.99607724,
#        0.99616015, 0.99624129, 0.99632012, 0.99639391, 0.99646711,
#        0.99653712, 0.99660514, 0.99667232, 0.99673639, 0.99679906,
#        0.9968587 , 0.99691614, 0.9969725 , 0.99702791, 0.99708073,
#        0.99713315, 0.99718331, 0.99723171, 0.99727956, 0.99732664,
#        0.99737252, 0.99741831, 0.99746035, 0.99750106, 0.99754147,
#        0.99758111, 0.9976202 , 0.99765859, 0.99769659, 0.99773307,
#        0.99776898, 0.99780363, 0.9978367 , 0.99786867, 0.99789992,
#        0.99793065, 0.99796069, 0.99798973, 0.99801833, 0.99804613,
#        0.99807386, 0.99810042, 0.9981266 , 0.99815234, 0.99817753,
#        0.99820227, 0.99822629, 0.99824988, 0.99827311, 0.99829629,
#        0.99831863, 0.99833987, 0.9983608 , 0.99838157, 0.99840223,
#        0.99842222, 0.99844198, 0.99846097, 0.99847947, 0.99849784,
#        0.99851558, 0.99853326, 0.99855042, 0.99856752, 0.99858441,
#        0.99860116, 0.99861711, 0.99863281, 0.99864798, 0.99866311,
#        0.99867792, 0.99869242, 0.99870653, 0.99872046, 0.9987342 ,
#        0.99874779, 0.99876104, 0.9987741 , 0.99878705, 0.99879962,
#        0.99881195, 0.99882417, 0.99883629, 0.99884825, 0.99885997,
#        0.99887154, 0.99888293, 0.99889418, 0.99890533, 0.99891635,
#        0.9989273 , 0.99893809, 0.99894856, 0.99895884, 0.99896897,
#        0.99897893, 0.99898877, 0.99899848, 0.9990081 , 0.99901765,
#        0.99902714, 0.99903651, 0.99904573, 0.99905489, 0.99906388,
#        0.99907271, 0.9990814 , 0.99909002, 0.99909846, 0.99910672,
#        0.99911491, 0.99912292, 0.99913088, 0.99913878, 0.9991466 ,
#        0.99915437, 0.99916208, 0.9991697 , 0.99917712, 0.99918451,
#        0.99919173, 0.99919871, 0.99920567, 0.99921257, 0.99921941,
#        0.99922622, 0.999233  , 0.99923966, 0.9992462 , 0.99925269,
#        0.99925908, 0.99926542, 0.99927171, 0.9992779 , 0.99928402,
#        0.9992901 , 0.99929614, 0.99930213, 0.99930806, 0.99931388,
#        0.99931967, 0.99932539, 0.99933102, 0.99933663, 0.99934212,
#        0.99934754, 0.99935294, 0.99935832, 0.99936363, 0.9993689 ,
#        0.99937411, 0.99937925, 0.99938435, 0.99938938, 0.99939437,
#        0.99939928, 0.99940414, 0.99940897, 0.99941374, 0.99941847,
#        0.99942315, 0.99942782, 0.99943243, 0.99943696, 0.99944144,
#        0.99944589, 0.99945032, 0.99945469, 0.99945904, 0.99946333,
#        0.99946758, 0.99947174, 0.99947589, 0.99948002, 0.99948409,
#        0.99948814, 0.99949212, 0.99949607, 0.99950002, 0.99950395,
#        0.99950786, 0.99951172, 0.99951554, 0.99951932, 0.99952305,
#        0.99952676, 0.99953042, 0.99953403, 0.99953762, 0.9995412 ,
#        0.99954474, 0.99954824, 0.9995517 , 0.99955513, 0.99955853,
#        0.99956189, 0.99956523, 0.99956854, 0.99957182, 0.99957509,
#        0.99957832, 0.99958152, 0.99958469, 0.99958782, 0.99959093,
#        0.99959401, 0.99959707, 0.99960011, 0.99960315, 0.99960616,
#        0.99960915, 0.9996121 , 0.99961502, 0.99961793, 0.99962082,
#        0.99962367, 0.99962651, 0.9996293 , 0.99963207, 0.99963481,
#        0.99963755, 0.99964024, 0.99964291, 0.99964554, 0.99964815,
#        0.99965074, 0.99965331, 0.99965588, 0.9996584 , 0.99966092,
#        0.9996634 , 0.99966586, 0.99966829, 0.99967069, 0.99967309,
#        0.99967548, 0.99967784, 0.99968019, 0.99968253, 0.99968486,
#        0.99968715, 0.99968942, 0.99969168, 0.99969392, 0.99969615,
#        0.99969836, 0.99970057, 0.99970274, 0.99970491, 0.99970706,
#        0.99970919, 0.99971131, 0.99971341, 0.99971549, 0.99971756,
#        0.99971961, 0.99972164, 0.99972366, 0.99972566, 0.99972763,
#        0.9997296 , 0.99973155, 0.99973349, 0.99973541, 0.99973731,
#        0.9997392 , 0.99974109, 0.99974296, 0.99974481, 0.99974665,
#        0.99974849, 0.99975029, 0.99975208, 0.99975386, 0.99975563,
#        0.99975737, 0.9997591 , 0.99976082, 0.99976253, 0.99976423,
#        0.9997659 , 0.99976757, 0.99976924, 0.99977089, 0.99977253,
#        0.99977415, 0.99977577, 0.99977738, 0.99977896, 0.99978054,
#        0.99978212, 0.99978368, 0.99978523, 0.99978676, 0.99978828,
#        0.99978979, 0.99979129, 0.99979277, 0.99979425, 0.99979571,
#        0.99979715, 0.99979859, 0.99980002, 0.99980142, 0.99980282,
#        0.99980421, 0.99980559, 0.99980696, 0.99980833, 0.99980968,
#        0.99981102, 0.99981234, 0.99981366, 0.99981497, 0.99981627,
#        0.99981758, 0.99981885, 0.99982012, 0.99982139, 0.99982265,
#        0.9998239 , 0.99982515, 0.99982638, 0.9998276 , 0.99982881,
#        0.99983001, 0.99983121, 0.9998324 , 0.99983358, 0.99983475,
#        0.99983591, 0.99983706, 0.99983821, 0.99983935, 0.99984048,
#        0.99984161, 0.99984272, 0.99984384, 0.99984494, 0.99984604,
#        0.99984713, 0.99984821, 0.99984929, 0.99985036, 0.99985142,
#        0.99985246, 0.99985351, 0.99985454, 0.99985557, 0.9998566 ,
#        0.99985762, 0.99985864, 0.99985964, 0.99986064, 0.99986162,
#        0.9998626 , 0.99986358, 0.99986455, 0.99986551, 0.99986646,
#        0.9998674 , 0.99986834, 0.99986927, 0.99987019, 0.99987111,
#        0.99987203, 0.99987294, 0.99987384, 0.99987474, 0.99987563,
#        0.99987652, 0.99987739, 0.99987827, 0.99987913, 0.99987999,
#        0.99988084, 0.99988168, 0.99988252, 0.99988335, 0.99988417,
#        0.99988499, 0.99988581, 0.99988662, 0.99988742, 0.99988822,
#        0.99988902, 0.99988981, 0.99989059, 0.99989136, 0.99989213,
#        0.9998929 , 0.99989366, 0.99989442, 0.99989517, 0.99989592,
#        0.99989666, 0.99989739, 0.99989811, 0.99989883, 0.99989955,
#        0.99990026, 0.99990097, 0.99990167, 0.99990237, 0.99990307,
#        0.99990376, 0.99990444, 0.99990512, 0.9999058 , 0.99990647,
#        0.99990714, 0.9999078 , 0.99990845, 0.9999091 , 0.99990975,
#        0.99991039, 0.99991103, 0.99991166, 0.99991229, 0.99991292,
#        0.99991354, 0.99991416, 0.99991477, 0.99991538, 0.99991599,
#        0.9999166 , 0.9999172 , 0.99991779, 0.99991839, 0.99991897,
#        0.99991955, 0.99992013, 0.99992071, 0.99992128, 0.99992185,
#        0.99992241, 0.99992297, 0.99992353, 0.99992408, 0.99992463,
#        0.99992517, 0.99992571, 0.99992625, 0.99992678, 0.99992731,
#        0.99992783, 0.99992835, 0.99992887, 0.99992939, 0.9999299 ,
#        0.99993042, 0.99993092, 0.99993142, 0.99993192, 0.99993241,
#        0.99993291, 0.99993339, 0.99993388, 0.99993436, 0.99993484,
#        0.99993531, 0.99993579, 0.99993626, 0.99993672, 0.99993719,
#        0.99993765, 0.9999381 , 0.99993856, 0.99993901, 0.99993946,
#        0.9999399 , 0.99994035, 0.99994079, 0.99994122, 0.99994166,
#        0.99994209, 0.99994252, 0.99994294, 0.99994336, 0.99994378,
#        0.9999442 , 0.99994461, 0.99994502, 0.99994543, 0.99994583,
#        0.99994624, 0.99994663, 0.99994702, 0.99994741, 0.9999478 ,
#        0.99994819, 0.99994857, 0.99994895, 0.99994933, 0.9999497 ,
#        0.99995008, 0.99995045, 0.99995081, 0.99995118, 0.99995154,
#        0.9999519 , 0.99995226, 0.99995262, 0.99995298, 0.99995333,
#        0.99995368, 0.99995403, 0.99995437, 0.99995471, 0.99995505,
#        0.99995538, 0.99995572, 0.99995605, 0.99995638, 0.99995671,
#        0.99995704, 0.99995736, 0.99995768, 0.999958  , 0.99995832,
#        0.99995863, 0.99995895, 0.99995926, 0.99995957, 0.99995987,
#        0.99996018, 0.99996048, 0.99996078, 0.99996108, 0.99996138,
#        0.99996167, 0.99996196, 0.99996225, 0.99996253, 0.99996282,
#        0.9999631 , 0.99996338, 0.99996366, 0.99996393, 0.99996421,
#        0.99996448, 0.99996476, 0.99996502, 0.99996529, 0.99996556,
#        0.99996582, 0.99996608, 0.99996634, 0.9999666 , 0.99996686,
#        0.99996711, 0.99996736, 0.99996761, 0.99996786, 0.99996811,
#        0.99996836, 0.9999686 , 0.99996884, 0.99996908, 0.99996932,
#        0.99996956, 0.9999698 , 0.99997003, 0.99997026, 0.9999705 ,
#        0.99997073, 0.99997095, 0.99997118, 0.99997141, 0.99997163,
#        0.99997185, 0.99997207, 0.99997229, 0.99997251, 0.99997272,
#        0.99997293, 0.99997314, 0.99997335, 0.99997356, 0.99997377,
#        0.99997398, 0.99997419, 0.99997439, 0.99997459, 0.99997479,
#        0.99997499, 0.99997519, 0.99997538, 0.99997558, 0.99997577,
#        0.99997596, 0.99997615, 0.99997634, 0.99997653, 0.99997671,
#        0.9999769 , 0.99997708, 0.99997727, 0.99997745, 0.99997763,
#        0.99997781, 0.99997799, 0.99997817, 0.99997834, 0.99997851,
#        0.99997869, 0.99997886, 0.99997903, 0.9999792 , 0.99997937,
#        0.99997954, 0.9999797 , 0.99997987, 0.99998003, 0.99998019,
#        0.99998035, 0.99998051, 0.99998067, 0.99998083, 0.99998099,
#        0.99998114, 0.9999813 , 0.99998145, 0.9999816 , 0.99998175,
#        0.9999819 , 0.99998205, 0.9999822 , 0.99998235, 0.99998249,
#        0.99998264, 0.99998278, 0.99998293, 0.99998307, 0.99998321,
#        0.99998335, 0.99998349, 0.99998362, 0.99998376, 0.9999839 ,
#        0.99998403, 0.99998417, 0.9999843 , 0.99998443, 0.99998456,
#        0.9999847 , 0.99998483, 0.99998495, 0.99998508, 0.99998521,
#        0.99998534, 0.99998546, 0.99998559, 0.99998571, 0.99998583,
#        0.99998595, 0.99998607, 0.9999862 , 0.99998631, 0.99998643,
#        0.99998655, 0.99998667, 0.99998678, 0.9999869 , 0.99998701,
#        0.99998712, 0.99998724, 0.99998735, 0.99998746, 0.99998756,
#        0.99998767, 0.99998778, 0.99998788, 0.99998799, 0.9999881 ,
#        0.9999882 , 0.9999883 , 0.99998841, 0.99998851, 0.99998861,
#        0.99998871, 0.99998881, 0.99998891, 0.99998901, 0.99998911,
#        0.9999892 , 0.9999893 , 0.99998939, 0.99998949, 0.99998958,
#        0.99998968, 0.99998977, 0.99998987, 0.99998996, 0.99999005,
#        0.99999014, 0.99999023, 0.99999032, 0.99999041, 0.9999905 ,
#        0.99999059, 0.99999067, 0.99999076, 0.99999085, 0.99999093,
#        0.99999102, 0.9999911 , 0.99999119, 0.99999127, 0.99999135,
#        0.99999143, 0.99999151, 0.99999159, 0.99999167, 0.99999175,
#        0.99999183, 0.99999191, 0.99999199, 0.99999206, 0.99999214,
#        0.99999221, 0.99999229, 0.99999236, 0.99999244, 0.99999251,
#        0.99999258, 0.99999266, 0.99999273, 0.9999928 , 0.99999287,
#        0.99999294, 0.99999301, 0.99999308, 0.99999315, 0.99999321,
#        0.99999328, 0.99999335, 0.99999342, 0.99999348, 0.99999355,
#        0.99999361, 0.99999368, 0.99999374, 0.9999938 , 0.99999387,
#        0.99999393, 0.99999399, 0.99999405, 0.99999412, 0.99999418,
#        0.99999424, 0.9999943 , 0.99999436, 0.99999442, 0.99999447,
#        0.99999453, 0.99999459, 0.99999465, 0.9999947 , 0.99999476,
#        0.99999482, 0.99999487, 0.99999493, 0.99999498, 0.99999504,
#        0.99999509, 0.99999515, 0.9999952 , 0.99999525, 0.9999953 ,
#        0.99999536, 0.99999541, 0.99999546, 0.99999551, 0.99999556,
#        0.99999561, 0.99999566, 0.99999571, 0.99999575, 0.9999958 ,
#        0.99999585, 0.9999959 , 0.99999595, 0.99999599, 0.99999604,
#        0.99999609, 0.99999613, 0.99999618, 0.99999622, 0.99999627,
#        0.99999631, 0.99999636, 0.9999964 , 0.99999644, 0.99999649,
#        0.99999653, 0.99999657, 0.99999661, 0.99999666, 0.9999967 ,
#        0.99999674, 0.99999678, 0.99999682, 0.99999686, 0.9999969 ,
#        0.99999694, 0.99999698, 0.99999702, 0.99999706, 0.9999971 ,
#        0.99999714, 0.99999718, 0.99999721, 0.99999725, 0.99999729,
#        0.99999732, 0.99999736, 0.9999974 , 0.99999743, 0.99999747,
#        0.9999975 , 0.99999754, 0.99999757, 0.99999761, 0.99999764,
#        0.99999767, 0.99999771, 0.99999774, 0.99999777, 0.99999781,
#        0.99999784, 0.99999787, 0.9999979 , 0.99999793, 0.99999796,
#        0.999998  , 0.99999803, 0.99999806, 0.99999809, 0.99999812,
#        0.99999815, 0.99999818, 0.9999982 , 0.99999823, 0.99999826,
#        0.99999829, 0.99999832, 0.99999835, 0.99999837, 0.9999984 ,
#        0.99999843, 0.99999846, 0.99999848, 0.99999851, 0.99999854,
#        0.99999856, 0.99999859, 0.99999861, 0.99999864, 0.99999866,
#        0.99999869, 0.99999871, 0.99999874, 0.99999876, 0.99999879,
#        0.99999881, 0.99999884, 0.99999886, 0.99999888, 0.99999891,
#        0.99999893, 0.99999895, 0.99999897, 0.999999  , 0.99999902,
#        0.99999904, 0.99999906, 0.99999908, 0.99999911, 0.99999913,
#        0.99999915, 0.99999917, 0.99999919, 0.99999921, 0.99999923,
#        0.99999925, 0.99999927, 0.99999929, 0.99999931, 0.99999933,
#        0.99999935, 0.99999937, 0.99999938, 0.9999994 , 0.99999942,
#        0.99999944, 0.99999946, 0.99999948, 0.99999949, 0.99999951,
#        0.99999953, 0.99999955, 0.99999956, 0.99999958, 0.9999996 ,
#        0.99999961, 0.99999963, 0.99999964, 0.99999966, 0.99999968,
#        0.99999969, 0.99999971, 0.99999972, 0.99999974, 0.99999975,
#        0.99999976, 0.99999978, 0.99999979, 0.99999981, 0.99999982,
#        0.99999983, 0.99999985, 0.99999986, 0.99999987, 0.99999989,
#        0.9999999 , 0.99999991, 0.99999992, 0.99999993, 0.99999995,
#        0.99999996, 0.99999997, 0.99999998, 0.99999999, 1.        ])

# %%
from matplotlib import pyplot as plt
plt.plot(explained_variance)

# %%
plt.plot(pca_res[:,0],pca_res[:,1],'bo',markersize=1,alpha=0.3)

# %%
plt.plot(pca_res[:,1],pca_res[:,2],'bo',markersize=1,alpha=0.3)

# %%
from plotnine import *

# %% [markdown]
# ## We subset to 50 pc's

# %%
for locus in loci: 
    gc_content=open("../compute_gc/gc."+locus+".bed",'r').read().strip().split('\n')
    gc_vals=np.expand_dims(np.asarray([float(i.split('\t')[-1]) for i in gc_content]),axis=1)
    #add gc column to embedding 
    pca_with_gc=np.concatenate((pca_res[locus_to_pos[locus][0]:locus_to_pos[locus][1],0:50],gc_vals),axis=1)
    coords=all_bed_entries[locus_to_pos[locus][0]:locus_to_pos[locus][1]]
    print(pca_with_gc.shape)
    #save 
    np.savez_compressed(locus+"_FC_layer_NN_embeddings.regression.gc.top50pcs.npz",bed_entries=coords,embeddings=pca_with_gc)
    pca_2d = umap.UMAP(random_state=42).fit_transform(pca_with_gc)
    df_pca=pd.DataFrame.from_dict({'pca_2d_1':pca_2d[:,0],
                              'pca_2d_2':pca_2d[:,1],
                              'gc':gc_vals.squeeze()})
    print((ggplot(df_pca,aes(x='pca_2d_1', y='pca_2d_2',color='gc'))+
       geom_point(size=1,alpha=0.3)+
       ggtitle(locus+", Regression, FC, 50 PCs+GC content")))
    un_corrected_fc_embeddings_2d = umap.UMAP(random_state=42).fit_transform(all_embeddings[locus_to_pos[locus][0]:locus_to_pos[locus][1]])
    df_fc=pd.DataFrame.from_dict({'un_corrected_fc_1':un_corrected_fc_embeddings_2d[:,0],
                              'un_corrected_fc_2':un_corrected_fc_embeddings_2d[:,1],
                              'gc':gc_vals.squeeze()})
    print((ggplot(df_fc,aes(x='un_corrected_fc_1', y='un_corrected_fc_2',color='gc'))+
       geom_point(size=1,alpha=0.3)+
       ggtitle(locus+", Regression, FC,1kb embedding")))
# Out:
# (8001, 51)
# <ggplot: (-9223363302250526755)>
# <ggplot: (-9223363302250991742)>
# (8001, 51)
# <ggplot: (8734604244516)>
# <ggplot: (-9223363302250952199)>
# (8001, 51)
# <ggplot: (8734604244516)>
# <ggplot: (-9223363302224641087)>
# (8174, 51)
# <ggplot: (-9223363302250952199)>
# <ggplot: (8734630120880)>

# %%
model
# Out:
# '/srv/scratch/annashch/bias_correction/gc_covariate/regression/H1ESC/DNASE.H1ESC.regressionlabels.withgc.8'

# %%
from kerasAC.custom_losses import *
from kerasAC.metrics import recall, specificity, fpr, fnr, precision, f1
from keras.models import load_model
import pdb
custom_objects={"recall":recall,
                "sensitivity":recall,
                "specificity":specificity,
                "fpr":fpr,
                "fnr":fnr,
                "precision":precision,
                "f1":f1,
                "ambig_binary_crossentropy":ambig_binary_crossentropy,
                "ambig_mean_absolute_error":ambig_mean_absolute_error,
                "ambig_mean_squared_error":ambig_mean_squared_error}
model=load_model(model,custom_objects=custom_objects)

# %%
all_n=np.zeros((1,1,1000,4))
n_gc=np.zeros((1,))

# %%
model.predict([all_n,n_gc])
# Out:
# array([[-0.00638924]], dtype=float32)
